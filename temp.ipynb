# %%
import cv2
import csv
import numpy as np
import os
import pickle
from ultralytics import YOLO  
from sort import *

# %%
# --- Load reference histogram for red light detection ---
def load_histogram(file_path):
    """Load a precomputed histogram from a pickle file."""
    with open(file_path, 'rb') as file:
        histogram = pickle.load(file)
    return histogram

def calculate_histogram(image, bbox):
    """Calculate and normalize the histogram for a region in the image."""
    height, width, _ = image.shape
    x_center, y_center, box_width, box_height = bbox

    x_min = int((x_center - box_width / 2) * width)
    x_max = int((x_center + box_width / 2) * width)
    y_min = int((y_center - box_height / 2) * height)
    y_max = int((y_center + box_height / 2) * height)

    roi = image[y_min:y_max, x_min:x_max]
    histogram = cv2.calcHist([roi], [0, 1, 2], None, [8, 8, 8], [0, 256, 0, 256, 0, 256])
    histogram = cv2.normalize(histogram, histogram).flatten()
    return histogram

def compare_histograms(hist1, hist2):
    """Compare two histograms using correlation; returns a similarity score."""
    return cv2.compareHist(hist1, hist2, cv2.HISTCMP_CORREL)

# Arrow drawing for highlighting violations
def draw_arrow(frame, x1, y1, x2, y2):
    """
    Draw a large, filled downward-pointing arrow above the bounding box (x1,y1,x2,y2).
    Used to indicate a violation.
    """
    center_x = (x1 + x2) // 2
    top_y = y1 - 150  # start the arrow 150px above the vehicle's top
    arrow_width = 50
    arrow_height = 100
    shaft_width = 20

    # Define triangle (arrowhead) points and rectangle (shaft) points
    arrow_tip = (center_x, y1)
    left_corner = (center_x - arrow_width, top_y + arrow_height)
    right_corner = (center_x + arrow_width, top_y + arrow_height)
    shaft_top_left = (center_x - shaft_width, top_y)
    shaft_top_right = (center_x + shaft_width, top_y)
    shaft_bottom_left = (center_x - shaft_width, top_y + arrow_height)
    shaft_bottom_right = (center_x + shaft_width, top_y + arrow_height)

    arrow_head = np.array([arrow_tip, left_corner, right_corner], np.int32)
    arrow_shaft = np.array([shaft_top_left, shaft_bottom_left, shaft_bottom_right, shaft_top_right], np.int32)
    color = (0, 0, 255)  # red color for the arrow
    cv2.fillPoly(frame, [arrow_head], color)
    cv2.fillPoly(frame, [arrow_shaft], color)

def is_within_path(cx, cy, path_bbox, frame_shape):
    """Check if a point (car center) lies within the specified path region (normalized coords)."""
    height, width, _ = frame_shape
    x_center, y_center, box_width, box_height = path_bbox
    # Convert normalized path_bbox to pixel region
    x_min = int((x_center - box_width / 2) * width)
    x_max = int((x_center + box_width / 2) * width)
    y_min = int((y_center - box_height / 2) * height)
    y_max = int((y_center + box_height / 2) * height)
    return (x_min <= cx <= x_max) and (y_min <= cy <= y_max)

def point_side(point, line_start, line_end):
    """
    Determine which side of a directed line segment the point lies on.
    Returns a positive value if 'point' is to the left of the line (line_start->line_end vector),
    negative if to the right, and 0 if on the line.
    """
    return ((point[0] - line_start[0]) * (line_end[1] - line_start[1]) - 
            (point[1] - line_start[1]) * (line_end[0] - line_start[0]))

# --- Initialize model, tracker, and reference data ---
model = YOLO('yolov8n.pt')  # YOLOv8 model (using the small 'n' variant for speed)
tracker = Sort()            # Initialize SORT tracker for object tracking
reference_histogram = load_histogram('./Histogram/modelTown_histogram.pkl')  # load the reference red-light histogram

# Define the region of the frame where the traffic light appears (normalized coordinates)
# These should be set based on calibration for the specific camera view:
signal_bbox = (0.485879, 0.577487, 0.016630, 0.051067)   # Example normalized [x_center, y_center, width, height] for traffic light ROI
# Define the region of interest on the road where vehicle detection is considered (path area)
path_bbox   = (0.901061, 0.730515, 0.197877, 0.199434)   # Example normalized [x_center, y_center, width, height] for road section

# Define line positions for lower (stop line) and upper (violation line) in pixel coordinates
# These should be determined from the perspective of the camera for the specific intersection.

upper_line_start = (1389, 699)
upper_line_end = (1859, 666)
lower_line_start = (1912, 842)
lower_line_end = (1332, 1061)


threshold = 0.12  # similarity threshold above which the signal is considered "Red"

# --- Set up video capture from the mobile camera IP stream ---
ip_camera_url = "http://192.168.10.28:8080/video"  # replace with your phone's IP Webcam URL
cap = cv2.VideoCapture(ip_camera_url)
if not cap.isOpened():
    print("Error: Unable to access the IP camera stream.")
    exit()

# Prepare video writer to save output video
fps = cap.get(cv2.CAP_PROP_FPS)
if fps is None or fps <= 1:
    fps = 20  # default to 20 FPS if FPS not reported by the stream
frame_width  = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
os.makedirs('./result', exist_ok=True) 
output_path = "./result/violation_output.mp4"
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
video_writer = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

track_states = {}  # Dictionary to hold tracking state (entered/violated) for each vehicle ID

# --- Main loop: read frames and process ---
while True:
    ret, frame = cap.read()
    if not ret:
        print("Stream ended or cannot read frame.")
        break

    # 1. Draw the lane boundary lines on the frame
    cv2.line(frame, upper_line_start, upper_line_end, (0, 255, 255), 2)  # upper line in yellow
    cv2.line(frame, lower_line_start, lower_line_end, (255, 0, 0), 2)    # lower line in blue

    # 2. Determine traffic light state using histogram comparison
    frame_hist = calculate_histogram(frame, signal_bbox)
    score = compare_histograms(frame_hist, reference_histogram)
    # Draw the signal ROI box and the current similarity score
    h, w, _ = frame.shape
    sx, sy, sw, sh = signal_bbox
    sx_min = int((sx - sw/2) * w); sx_max = int((sx + sw/2) * w)
    sy_min = int((sy - sh/2) * h); sy_max = int((sy + sh/2) * h)
    cv2.rectangle(frame, (sx_min, sy_min), (sx_max, sy_max), (255, 255, 255), 2)
    cv2.putText(frame, f"Score: {score:.2f}", (sx_min, sy_max + 20),
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 2)

    # (Optional) Draw the detection zone (path) bounding box on the frame for visualization
    px, py, pw, ph = path_bbox
    px_min = int((px - pw/2) * w); px_max = int((px + pw/2) * w)
    py_min = int((py - ph/2) * h); py_max = int((py + ph/2) * h)
    cv2.rectangle(frame, (px_min, py_min), (px_max, py_max), (0, 255, 0), 2)

    # 3. If the signal is Red (histogram similarity above threshold), perform vehicle detection
    if score > threshold:
        results = model(frame)  # run YOLOv8 on the frame
        detections = []
        # Filter detections for cars (class id 2 for COCO, which is "car")
        for det in results[0].boxes.data.cpu().numpy():
            x1, y1, x2, y2, conf, cls_id = det[:6]
            if int(cls_id) == 2:  # class 2 = car
                detections.append([x1, y1, x2, y2, conf])
        detections = np.array(detections) if len(detections) > 0 else np.empty((0, 5))
        # Update tracker with current detections
        tracked_objects = tracker.update(detections)

        # 4. Process tracked vehicles for violation logic
        for x1, y1, x2, y2, track_id in tracked_objects:
            track_id = int(track_id)
            # Compute the center of the bounding box
            center_x = int((x1 + x2) / 2)
            center_y = int((y1 + y2) / 2)

            # Only consider vehicles within the defined path/road area
            if not is_within_path(center_x, center_y, path_bbox, frame.shape):
                continue

            # Update tracking state: check if vehicle has entered and then crossed the lines
            if track_id not in track_states:
                # If the vehicle has passed the **lower (stop) line**, mark it as "entered"
                if point_side((center_x, center_y), lower_line_start, lower_line_end) > 0:
                    track_states[track_id] = {"entered": True, "violated": False}
            else:
                # If already entered and now passes the **upper line**, mark as a violation
                if (track_states[track_id]["entered"] and not track_states[track_id]["violated"] and 
                        point_side((center_x, center_y), upper_line_start, upper_line_end) > 0):
                    track_states[track_id]["violated"] = True

            # Determine if this vehicle is in violation
            violated = track_states.get(track_id, {}).get("violated", False)
            # Draw the vehicle's bounding box (red if violated, green if not yet violated)
            color = (0, 0, 255) if violated else (0, 255, 0)
            cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), color, 2)
            # If violation occurred, draw the downward arrow indicator
            if violated:
                draw_arrow(frame, int(x1), int(y1), int(x2), int(y2))
                # (Optional: could log or save violation event details here)

        # Write this frame to the output video (only recording during red signal periods)
        video_writer.write(frame)
    else:
        # If the light is not red, we do not perform detection or tracking (for efficiency),
        # and we skip writing the frame to the output video.
        pass

    # 5. Display the frame with annotations in a window
    cv2.imshow("Red Light Violation Detection", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Clean up resources
cap.release()
video_writer.release()
cv2.destroyAllWindows()
# Out:
# [mjpeg @ 0xf872280] overread 8
# [mjpeg @ 0xf872280] overread 8
# 0: 384x640 7 persons, 8 cars, 4 motorcycles, 241.6ms
# Speed: 3.3ms preprocess, 241.6ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 8 cars, 4 motorcycles, 1 truck, 1 traffic light, 192.0ms
# Speed: 5.1ms preprocess, 192.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 7 cars, 2 motorcycles, 1 truck, 173.5ms
# Speed: 4.1ms preprocess, 173.5ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 4 cars, 3 motorcycles, 1 truck, 186.6ms
# Speed: 6.0ms preprocess, 186.6ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 2 motorcycles, 211.5ms
# Speed: 4.5ms preprocess, 211.5ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 3 cars, 3 motorcycles, 1 truck, 168.6ms
# Speed: 7.1ms preprocess, 168.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 cars, 3 motorcycles, 1 truck, 191.5ms
# Speed: 4.9ms preprocess, 191.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 5 cars, 2 motorcycles, 1 traffic light, 1 umbrella, 196.1ms
# Speed: 10.1ms preprocess, 196.1ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 5 cars, 3 motorcycles, 1 traffic light, 1 umbrella, 213.8ms
# Speed: 4.2ms preprocess, 213.8ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 6 cars, 1 motorcycle, 1 truck, 189.5ms
# Speed: 4.8ms preprocess, 189.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 7 cars, 2 motorcycles, 1 truck, 1 traffic light, 168.3ms
# Speed: 6.4ms preprocess, 168.3ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 6 cars, 2 motorcycles, 1 truck, 174.8ms
# Speed: 4.1ms preprocess, 174.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 5 cars, 1 motorcycle, 1 truck, 204.3ms
# Speed: 4.8ms preprocess, 204.3ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 5 cars, 2 motorcycles, 1 truck, 185.4ms
# Speed: 7.1ms preprocess, 185.4ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 5 cars, 2 motorcycles, 1 umbrella, 193.2ms
# Speed: 7.8ms preprocess, 193.2ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 5 cars, 1 motorcycle, 1 truck, 180.8ms
# Speed: 6.5ms preprocess, 180.8ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 6 cars, 1 motorcycle, 1 truck, 1 umbrella, 199.8ms
# Speed: 9.2ms preprocess, 199.8ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 6 cars, 1 motorcycle, 1 truck, 193.1ms
# Speed: 5.9ms preprocess, 193.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 5 cars, 1 motorcycle, 1 bus, 176.2ms
# Speed: 3.9ms preprocess, 176.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 1 motorcycle, 1 truck, 175.6ms
# Speed: 5.1ms preprocess, 175.6ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 5 cars, 1 truck, 207.7ms
# Speed: 7.6ms preprocess, 207.7ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 5 cars, 1 umbrella, 252.7ms
# Speed: 9.0ms preprocess, 252.7ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 5 cars, 1 truck, 184.6ms
# Speed: 9.8ms preprocess, 184.6ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 5 cars, 1 motorcycle, 1 truck, 214.9ms
# Speed: 4.2ms preprocess, 214.9ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 4 cars, 1 umbrella, 208.0ms
# Speed: 8.0ms preprocess, 208.0ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 4 cars, 1 umbrella, 215.1ms
# Speed: 8.5ms preprocess, 215.1ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 1 motorcycle, 1 truck, 1 umbrella, 188.9ms
# Speed: 5.3ms preprocess, 188.9ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 cars, 1 truck, 1 umbrella, 183.6ms
# Speed: 6.2ms preprocess, 183.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 cars, 1 truck, 1 umbrella, 209.7ms
# Speed: 4.7ms preprocess, 209.7ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 1 umbrella, 173.3ms
# Speed: 4.7ms preprocess, 173.3ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 1 umbrella, 189.8ms
# Speed: 4.4ms preprocess, 189.8ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 8 cars, 1 truck, 1 umbrella, 191.8ms
# Speed: 7.3ms preprocess, 191.8ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 6 cars, 1 truck, 1 umbrella, 179.4ms
# Speed: 5.8ms preprocess, 179.4ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 5 cars, 1 motorcycle, 1 truck, 1 umbrella, 197.9ms
# Speed: 5.8ms preprocess, 197.9ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 7 cars, 1 truck, 1 umbrella, 210.2ms
# Speed: 6.0ms preprocess, 210.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 7 cars, 1 umbrella, 181.8ms
# Speed: 7.0ms preprocess, 181.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 6 cars, 1 truck, 1 umbrella, 188.7ms
# Speed: 4.9ms preprocess, 188.7ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bicycle, 3 cars, 3 motorcycles, 184.6ms
# Speed: 5.0ms preprocess, 184.6ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 car, 3 motorcycles, 1 umbrella, 181.5ms
# Speed: 6.2ms preprocess, 181.5ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 car, 3 motorcycles, 1 umbrella, 211.2ms
# Speed: 4.0ms preprocess, 211.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 2 cars, 4 motorcycles, 199.0ms
# Speed: 4.8ms preprocess, 199.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 3 cars, 3 motorcycles, 1 umbrella, 182.0ms
# Speed: 6.4ms preprocess, 182.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 3 cars, 3 motorcycles, 1 umbrella, 188.3ms
# Speed: 4.3ms preprocess, 188.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 cars, 3 motorcycles, 192.0ms
# Speed: 7.6ms preprocess, 192.0ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 3 cars, 1 truck, 176.3ms
# Speed: 5.7ms preprocess, 176.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 3 cars, 1 truck, 1 umbrella, 196.3ms
# Speed: 8.9ms preprocess, 196.3ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 3 cars, 1 motorcycle, 1 umbrella, 239.2ms
# Speed: 6.6ms preprocess, 239.2ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 4 cars, 1 umbrella, 194.4ms
# Speed: 4.8ms preprocess, 194.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 4 cars, 2 motorcycles, 1 truck, 1 umbrella, 192.0ms
# Speed: 5.8ms preprocess, 192.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 5 cars, 1 motorcycle, 2 trucks, 1 umbrella, 196.9ms
# Speed: 11.4ms preprocess, 196.9ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 4 cars, 3 motorcycles, 1 truck, 206.5ms
# Speed: 5.3ms preprocess, 206.5ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 9 cars, 4 motorcycles, 2 trucks, 197.4ms
# Speed: 3.3ms preprocess, 197.4ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 9 cars, 2 motorcycles, 198.5ms
# Speed: 3.1ms preprocess, 198.5ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 6 cars, 2 motorcycles, 172.9ms
# Speed: 8.0ms preprocess, 172.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 5 cars, 4 motorcycles, 1 truck, 190.2ms
# Speed: 4.5ms preprocess, 190.2ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 6 cars, 3 motorcycles, 1 truck, 199.3ms
# Speed: 2.8ms preprocess, 199.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 2 motorcycles, 1 truck, 189.7ms
# Speed: 3.4ms preprocess, 189.7ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 6 cars, 2 motorcycles, 1 truck, 166.2ms
# Speed: 7.2ms preprocess, 166.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 1 truck, 1 traffic light, 194.3ms
# Speed: 5.4ms preprocess, 194.3ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 5 cars, 2 motorcycles, 1 truck, 1 traffic light, 216.9ms
# Speed: 5.9ms preprocess, 216.9ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 5 cars, 1 motorcycle, 1 truck, 1 traffic light, 197.0ms
# Speed: 3.9ms preprocess, 197.0ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 1 truck, 1 traffic light, 189.8ms
# Speed: 4.4ms preprocess, 189.8ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 3 cars, 1 truck, 1 traffic light, 212.0ms
# Speed: 4.6ms preprocess, 212.0ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 4 cars, 1 motorcycle, 1 traffic light, 2 umbrellas, 177.9ms
# Speed: 5.5ms preprocess, 177.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 6 cars, 2 motorcycles, 1 traffic light, 197.9ms
# Speed: 11.2ms preprocess, 197.9ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 4 cars, 1 traffic light, 1 umbrella, 190.2ms
# Speed: 8.6ms preprocess, 190.2ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 4 cars, 1 traffic light, 2 umbrellas, 190.3ms
# Speed: 7.2ms preprocess, 190.3ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 1 traffic light, 1 umbrella, 183.4ms
# Speed: 7.7ms preprocess, 183.4ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 6 cars, 1 traffic light, 178.3ms
# Speed: 4.2ms preprocess, 178.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 5 cars, 1 traffic light, 196.0ms
# Speed: 4.4ms preprocess, 196.0ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 5 cars, 1 traffic light, 1 umbrella, 173.0ms
# Speed: 4.3ms preprocess, 173.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 4 cars, 1 traffic light, 188.8ms
# Speed: 8.0ms preprocess, 188.8ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 1 umbrella, 215.3ms
# Speed: 2.7ms preprocess, 215.3ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 3 cars, 1 umbrella, 178.2ms
# Speed: 4.9ms preprocess, 178.2ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 cars, 1 umbrella, 220.0ms
# Speed: 5.1ms preprocess, 220.0ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 cars, 1 umbrella, 184.9ms
# Speed: 7.6ms preprocess, 184.9ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 199.6ms
# Speed: 3.9ms preprocess, 199.6ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 1 truck, 187.2ms
# Speed: 4.4ms preprocess, 187.2ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 cars, 1 umbrella, 172.1ms
# Speed: 8.5ms preprocess, 172.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 5 cars, 1 traffic light, 1 umbrella, 173.6ms
# Speed: 4.0ms preprocess, 173.6ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 3 cars, 1 traffic light, 1 umbrella, 178.0ms
# Speed: 4.8ms preprocess, 178.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 4 cars, 1 truck, 1 traffic light, 1 umbrella, 422.2ms
# Speed: 4.2ms preprocess, 422.2ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 9 cars, 1 truck, 1 traffic light, 1 umbrella, 204.5ms
# Speed: 8.1ms preprocess, 204.5ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 7 cars, 1 truck, 2 umbrellas, 206.0ms
# Speed: 5.9ms preprocess, 206.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 9 cars, 1 truck, 1 umbrella, 179.8ms
# Speed: 5.7ms preprocess, 179.8ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 3 cars, 2 motorcycles, 1 traffic light, 2 umbrellas, 206.4ms
# Speed: 8.1ms preprocess, 206.4ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 3 cars, 2 motorcycles, 1 umbrella, 204.0ms
# Speed: 7.6ms preprocess, 204.0ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 5 cars, 3 motorcycles, 1 traffic light, 1 umbrella, 195.2ms
# Speed: 4.4ms preprocess, 195.2ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 5 cars, 3 motorcycles, 1 traffic light, 1 umbrella, 203.8ms
# Speed: 7.2ms preprocess, 203.8ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 5 cars, 2 motorcycles, 1 traffic light, 1 umbrella, 205.7ms
# Speed: 9.7ms preprocess, 205.7ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 6 cars, 1 motorcycle, 203.5ms
# Speed: 8.4ms preprocess, 203.5ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 4 cars, 3 motorcycles, 187.1ms
# Speed: 8.4ms preprocess, 187.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 4 cars, 3 motorcycles, 195.4ms
# Speed: 5.4ms preprocess, 195.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 cars, 4 motorcycles, 209.9ms
# Speed: 8.7ms preprocess, 209.9ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 4 cars, 1 motorcycle, 1 umbrella, 189.1ms
# Speed: 8.2ms preprocess, 189.1ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 3 cars, 2 motorcycles, 1 umbrella, 177.8ms
# Speed: 5.9ms preprocess, 177.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 cars, 3 motorcycles, 1 umbrella, 203.2ms
# Speed: 4.4ms preprocess, 203.2ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 3 cars, 6 motorcycles, 1 traffic light, 187.2ms
# Speed: 3.8ms preprocess, 187.2ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 cars, 4 motorcycles, 1 traffic light, 179.1ms
# Speed: 6.1ms preprocess, 179.1ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 3 cars, 2 motorcycles, 2 umbrellas, 178.0ms
# Speed: 4.2ms preprocess, 178.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 3 cars, 2 motorcycles, 1 traffic light, 1 umbrella, 191.6ms
# Speed: 5.2ms preprocess, 191.6ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 4 cars, 1 motorcycle, 2 trucks, 171.1ms
# Speed: 4.3ms preprocess, 171.1ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 5 cars, 1 truck, 180.9ms
# Speed: 3.6ms preprocess, 180.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 6 cars, 2 trucks, 1 traffic light, 191.5ms
# Speed: 5.5ms preprocess, 191.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 5 cars, 1 traffic light, 206.7ms
# Speed: 9.2ms preprocess, 206.7ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 6 cars, 1 bus, 198.6ms
# Speed: 4.4ms preprocess, 198.6ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 7 cars, 2 trucks, 196.6ms
# Speed: 9.2ms preprocess, 196.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 truck, 201.3ms
# Speed: 6.0ms preprocess, 201.3ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 4 cars, 2 motorcycles, 1 boat, 1 traffic light, 205.6ms
# Speed: 5.7ms preprocess, 205.6ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 cars, 2 motorcycles, 1 traffic light, 208.8ms
# Speed: 5.9ms preprocess, 208.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 4 cars, 1 traffic light, 211.6ms
# Speed: 9.8ms preprocess, 211.6ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 4 cars, 1 motorcycle, 1 traffic light, 181.5ms
# Speed: 3.4ms preprocess, 181.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 4 cars, 1 motorcycle, 1 traffic light, 212.9ms
# Speed: 7.6ms preprocess, 212.9ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 5 cars, 1 motorcycle, 1 traffic light, 213.0ms
# Speed: 6.8ms preprocess, 213.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 4 cars, 1 traffic light, 1 umbrella, 203.7ms
# Speed: 6.2ms preprocess, 203.7ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 4 cars, 1 traffic light, 195.7ms
# Speed: 6.5ms preprocess, 195.7ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 3 cars, 1 truck, 1 traffic light, 187.2ms
# Speed: 6.5ms preprocess, 187.2ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 1 traffic light, 190.2ms
# Speed: 4.1ms preprocess, 190.2ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 1 traffic light, 1 umbrella, 183.6ms
# Speed: 5.1ms preprocess, 183.6ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 3 cars, 1 umbrella, 196.6ms
# Speed: 4.2ms preprocess, 196.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 4 cars, 1 umbrella, 211.0ms
# Speed: 6.3ms preprocess, 211.0ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 4 cars, 1 umbrella, 232.2ms
# Speed: 5.4ms preprocess, 232.2ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 3 cars, 1 umbrella, 196.6ms
# Speed: 3.7ms preprocess, 196.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 3 cars, 1 traffic light, 195.0ms
# Speed: 4.9ms preprocess, 195.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 5 cars, 1 truck, 1 traffic light, 1 umbrella, 202.8ms
# Speed: 4.9ms preprocess, 202.8ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 5 cars, 1 truck, 213.1ms
# Speed: 5.1ms preprocess, 213.1ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 6 cars, 200.5ms
# Speed: 4.7ms preprocess, 200.5ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 5 cars, 1 traffic light, 1 umbrella, 188.8ms
# Speed: 7.4ms preprocess, 188.8ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 7 cars, 1 truck, 1 traffic light, 1 umbrella, 185.6ms
# Speed: 4.1ms preprocess, 185.6ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 6 cars, 1 truck, 1 traffic light, 1 umbrella, 190.1ms
# Speed: 6.7ms preprocess, 190.1ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 5 cars, 1 truck, 1 traffic light, 1 umbrella, 234.8ms
# Speed: 9.8ms preprocess, 234.8ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 6 cars, 1 truck, 1 traffic light, 1 umbrella, 197.1ms
# Speed: 5.0ms preprocess, 197.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 1 truck, 1 traffic light, 1 umbrella, 186.4ms
# Speed: 5.9ms preprocess, 186.4ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 6 cars, 1 truck, 1 traffic light, 1 umbrella, 212.8ms
# Speed: 6.0ms preprocess, 212.8ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 6 cars, 1 truck, 1 traffic light, 1 umbrella, 283.6ms
# Speed: 8.0ms preprocess, 283.6ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 2 cars, 3 motorcycles, 1 traffic light, 208.3ms
# Speed: 9.7ms preprocess, 208.3ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 2 cars, 4 motorcycles, 1 traffic light, 189.0ms
# Speed: 8.6ms preprocess, 189.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 3 cars, 3 motorcycles, 1 traffic light, 175.7ms
# Speed: 5.5ms preprocess, 175.7ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 2 cars, 5 motorcycles, 1 traffic light, 166.4ms
# Speed: 6.1ms preprocess, 166.4ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 3 cars, 4 motorcycles, 1 traffic light, 163.5ms
# Speed: 3.7ms preprocess, 163.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 cars, 5 motorcycles, 1 traffic light, 149.4ms
# Speed: 3.0ms preprocess, 149.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 5 cars, 1 motorcycle, 1 traffic light, 172.8ms
# Speed: 3.8ms preprocess, 172.8ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 5 cars, 2 motorcycles, 1 traffic light, 163.4ms
# Speed: 4.8ms preprocess, 163.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 6 cars, 2 motorcycles, 1 traffic light, 179.5ms
# Speed: 7.6ms preprocess, 179.5ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 4 cars, 1 traffic light, 173.4ms
# Speed: 3.5ms preprocess, 173.4ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 5 cars, 3 motorcycles, 1 traffic light, 162.1ms
# Speed: 3.1ms preprocess, 162.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 4 cars, 2 motorcycles, 1 traffic light, 195.3ms
# Speed: 5.4ms preprocess, 195.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 4 cars, 2 motorcycles, 1 traffic light, 165.8ms
# Speed: 4.5ms preprocess, 165.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 7 cars, 1 bus, 1 truck, 1 traffic light, 150.0ms
# Speed: 4.9ms preprocess, 150.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 6 cars, 1 motorcycle, 1 traffic light, 168.5ms
# Speed: 8.0ms preprocess, 168.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 1 truck, 1 traffic light, 173.7ms
# Speed: 8.7ms preprocess, 173.7ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 1 motorcycle, 2 trucks, 161.5ms
# Speed: 4.1ms preprocess, 161.5ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 1 traffic light, 165.7ms
# Speed: 3.6ms preprocess, 165.7ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 5 cars, 1 motorcycle, 1 truck, 185.8ms
# Speed: 8.1ms preprocess, 185.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 5 cars, 1 traffic light, 175.4ms
# Speed: 3.3ms preprocess, 175.4ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 3 cars, 1 motorcycle, 1 traffic light, 179.0ms
# Speed: 6.4ms preprocess, 179.0ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 3 cars, 2 motorcycles, 1 traffic light, 146.6ms
# Speed: 4.9ms preprocess, 146.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 3 cars, 2 motorcycles, 1 traffic light, 179.9ms
# Speed: 5.4ms preprocess, 179.9ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 3 cars, 2 motorcycles, 1 traffic light, 171.3ms
# Speed: 5.9ms preprocess, 171.3ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 3 cars, 1 motorcycle, 1 traffic light, 159.4ms
# Speed: 4.7ms preprocess, 159.4ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 cars, 2 motorcycles, 1 traffic light, 155.3ms
# Speed: 4.7ms preprocess, 155.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 5 cars, 1 traffic light, 162.9ms
# Speed: 3.4ms preprocess, 162.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 5 cars, 1 traffic light, 168.8ms
# Speed: 4.7ms preprocess, 168.8ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 1 traffic light, 166.2ms
# Speed: 6.4ms preprocess, 166.2ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 3 cars, 1 traffic light, 165.2ms
# Speed: 5.3ms preprocess, 165.2ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 3 cars, 1 traffic light, 160.4ms
# Speed: 5.9ms preprocess, 160.4ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 1 umbrella, 172.8ms
# Speed: 5.4ms preprocess, 172.8ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 1 traffic light, 153.0ms
# Speed: 3.3ms preprocess, 153.0ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 1 traffic light, 155.0ms
# Speed: 6.8ms preprocess, 155.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 5 cars, 1 traffic light, 171.5ms
# Speed: 6.7ms preprocess, 171.5ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 1 traffic light, 157.2ms
# Speed: 4.0ms preprocess, 157.2ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 4 cars, 1 traffic light, 1 umbrella, 177.6ms
# Speed: 6.1ms preprocess, 177.6ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 3 cars, 1 traffic light, 1 umbrella, 157.0ms
# Speed: 2.9ms preprocess, 157.0ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 4 cars, 1 traffic light, 1 umbrella, 160.3ms
# Speed: 5.5ms preprocess, 160.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 4 cars, 1 traffic light, 159.0ms
# Speed: 6.4ms preprocess, 159.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 4 cars, 1 umbrella, 148.9ms
# Speed: 6.3ms preprocess, 148.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 4 cars, 2 motorcycles, 1 bus, 1 traffic light, 1 umbrella, 186.3ms
# Speed: 3.1ms preprocess, 186.3ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 4 cars, 1 motorcycle, 1 bus, 1 traffic light, 175.0ms
# Speed: 3.7ms preprocess, 175.0ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 4 cars, 1 motorcycle, 1 traffic light, 163.2ms
# Speed: 3.1ms preprocess, 163.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 6 cars, 1 motorcycle, 1 traffic light, 166.4ms
# Speed: 4.0ms preprocess, 166.4ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 2 motorcycles, 1 truck, 1 traffic light, 177.3ms
# Speed: 6.1ms preprocess, 177.3ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 5 cars, 2 motorcycles, 1 traffic light, 158.9ms
# Speed: 3.2ms preprocess, 158.9ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 5 cars, 2 motorcycles, 1 bus, 1 traffic light, 164.2ms
# Speed: 4.3ms preprocess, 164.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 4 cars, 2 motorcycles, 1 truck, 1 traffic light, 190.1ms
# Speed: 19.2ms preprocess, 190.1ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 4 cars, 4 motorcycles, 174.2ms
# Speed: 5.1ms preprocess, 174.2ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 5 cars, 2 motorcycles, 169.6ms
# Speed: 9.1ms preprocess, 169.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 4 cars, 2 motorcycles, 160.8ms
# Speed: 5.4ms preprocess, 160.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 2 motorcycles, 1 traffic light, 162.8ms
# Speed: 3.0ms preprocess, 162.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 4 cars, 3 motorcycles, 1 traffic light, 160.2ms
# Speed: 6.1ms preprocess, 160.2ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 3 cars, 3 motorcycles, 1 traffic light, 184.2ms
# Speed: 5.0ms preprocess, 184.2ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 3 cars, 6 motorcycles, 1 traffic light, 173.9ms
# Speed: 4.9ms preprocess, 173.9ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 4 cars, 3 motorcycles, 1 traffic light, 1 umbrella, 198.7ms
# Speed: 7.9ms preprocess, 198.7ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 cars, 3 motorcycles, 1 traffic light, 167.6ms
# Speed: 3.1ms preprocess, 167.6ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 4 cars, 2 motorcycles, 1 traffic light, 153.1ms
# Speed: 5.0ms preprocess, 153.1ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 4 cars, 2 motorcycles, 1 traffic light, 168.1ms
# Speed: 2.8ms preprocess, 168.1ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 4 cars, 3 motorcycles, 1 traffic light, 156.0ms
# Speed: 6.8ms preprocess, 156.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 5 cars, 1 motorcycle, 1 traffic light, 147.8ms
# Speed: 4.2ms preprocess, 147.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 3 cars, 4 motorcycles, 2 trucks, 1 umbrella, 170.1ms
# Speed: 8.5ms preprocess, 170.1ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 4 cars, 4 motorcycles, 1 truck, 1 traffic light, 179.8ms
# Speed: 5.7ms preprocess, 179.8ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 4 cars, 4 motorcycles, 1 truck, 179.0ms
# Speed: 4.1ms preprocess, 179.0ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 5 cars, 2 motorcycles, 1 truck, 180.9ms
# Speed: 4.6ms preprocess, 180.9ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 5 cars, 2 motorcycles, 2 trucks, 1 traffic light, 174.8ms
# Speed: 4.8ms preprocess, 174.8ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 5 cars, 3 motorcycles, 2 trucks, 1 traffic light, 215.2ms
# Speed: 7.4ms preprocess, 215.2ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 5 cars, 2 motorcycles, 1 truck, 1 traffic light, 181.0ms
# Speed: 4.6ms preprocess, 181.0ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 6 cars, 2 motorcycles, 1 traffic light, 171.8ms
# Speed: 5.9ms preprocess, 171.8ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 2 motorcycles, 1 traffic light, 188.7ms
# Speed: 4.6ms preprocess, 188.7ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 1 bus, 3 trucks, 183.3ms
# Speed: 4.9ms preprocess, 183.3ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 bus, 2 trucks, 151.7ms
# Speed: 3.8ms preprocess, 151.7ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 motorcycle, 1 truck, 1 traffic light, 150.7ms
# Speed: 3.2ms preprocess, 150.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 6 cars, 2 motorcycles, 1 truck, 163.9ms
# Speed: 7.3ms preprocess, 163.9ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 5 cars, 1 motorcycle, 1 truck, 148.0ms
# Speed: 5.7ms preprocess, 148.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 6 cars, 1 motorcycle, 1 truck, 1 traffic light, 171.0ms
# Speed: 3.3ms preprocess, 171.0ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 1 motorcycle, 1 truck, 1 traffic light, 202.9ms
# Speed: 7.4ms preprocess, 202.9ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 5 cars, 1 motorcycle, 1 truck, 1 traffic light, 164.3ms
# Speed: 3.2ms preprocess, 164.3ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 1 traffic light, 160.3ms
# Speed: 5.9ms preprocess, 160.3ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 5 cars, 1 traffic light, 181.8ms
# Speed: 6.4ms preprocess, 181.8ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 6 cars, 167.1ms
# Speed: 3.9ms preprocess, 167.1ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 4 cars, 1 traffic light, 151.3ms
# Speed: 7.2ms preprocess, 151.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 4 cars, 1 traffic light, 180.6ms
# Speed: 4.4ms preprocess, 180.6ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 4 cars, 1 motorcycle, 1 traffic light, 174.1ms
# Speed: 7.6ms preprocess, 174.1ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 4 cars, 1 traffic light, 1 umbrella, 170.5ms
# Speed: 3.0ms preprocess, 170.5ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 cars, 165.7ms
# Speed: 3.0ms preprocess, 165.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 cars, 1 traffic light, 1 umbrella, 151.5ms
# Speed: 7.9ms preprocess, 151.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 1 traffic light, 176.0ms
# Speed: 3.6ms preprocess, 176.0ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 6 cars, 1 traffic light, 1 umbrella, 157.4ms
# Speed: 4.3ms preprocess, 157.4ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 1 boat, 172.0ms
# Speed: 5.4ms preprocess, 172.0ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 1 truck, 1 boat, 182.9ms
# Speed: 4.2ms preprocess, 182.9ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 3 cars, 1 truck, 1 umbrella, 168.8ms
# Speed: 4.9ms preprocess, 168.8ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 3 cars, 186.5ms
# Speed: 4.4ms preprocess, 186.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 3 cars, 1 umbrella, 178.0ms
# Speed: 5.4ms preprocess, 178.0ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bicycle, 5 cars, 1 truck, 1 traffic light, 182.7ms
# Speed: 3.0ms preprocess, 182.7ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 5 cars, 1 truck, 1 traffic light, 1 umbrella, 197.6ms
# Speed: 9.1ms preprocess, 197.6ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 1 truck, 1 traffic light, 1 umbrella, 202.7ms
# Speed: 6.4ms preprocess, 202.7ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 6 cars, 1 truck, 1 traffic light, 1 umbrella, 197.3ms
# Speed: 5.6ms preprocess, 197.3ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 1 truck, 1 traffic light, 181.2ms
# Speed: 8.3ms preprocess, 181.2ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bicycle, 6 cars, 1 truck, 1 traffic light, 1 umbrella, 193.4ms
# Speed: 8.9ms preprocess, 193.4ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 1 truck, 1 traffic light, 1 umbrella, 204.8ms
# Speed: 3.4ms preprocess, 204.8ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 4 cars, 2 motorcycles, 1 truck, 1 traffic light, 177.6ms
# Speed: 3.5ms preprocess, 177.6ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 5 cars, 2 motorcycles, 1 truck, 1 traffic light, 1 umbrella, 182.1ms
# Speed: 3.7ms preprocess, 182.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 2 motorcycles, 1 truck, 1 traffic light, 177.2ms
# Speed: 3.6ms preprocess, 177.2ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 6 cars, 3 motorcycles, 1 truck, 1 traffic light, 392.4ms
# Speed: 21.7ms preprocess, 392.4ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 4 cars, 3 motorcycles, 187.3ms
# Speed: 8.6ms preprocess, 187.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 5 cars, 3 motorcycles, 1 traffic light, 186.3ms
# Speed: 8.9ms preprocess, 186.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 cars, 4 motorcycles, 186.6ms
# Speed: 3.8ms preprocess, 186.6ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 3 cars, 4 motorcycles, 194.7ms
# Speed: 3.6ms preprocess, 194.7ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 3 cars, 3 motorcycles, 1 traffic light, 181.1ms
# Speed: 4.7ms preprocess, 181.1ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 2 cars, 3 motorcycles, 1 umbrella, 172.2ms
# Speed: 4.9ms preprocess, 172.2ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 5 cars, 2 motorcycles, 1 traffic light, 177.1ms
# Speed: 4.0ms preprocess, 177.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 4 cars, 2 motorcycles, 1 traffic light, 190.1ms
# Speed: 5.3ms preprocess, 190.1ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 3 cars, 2 motorcycles, 1 truck, 1 umbrella, 202.2ms
# Speed: 6.1ms preprocess, 202.2ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 cars, 3 motorcycles, 1 truck, 1 traffic light, 218.5ms
# Speed: 5.0ms preprocess, 218.5ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 4 cars, 2 motorcycles, 1 truck, 1 traffic light, 1 umbrella, 206.7ms
# Speed: 6.7ms preprocess, 206.7ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 4 cars, 2 motorcycles, 1 truck, 1 traffic light, 197.3ms
# Speed: 8.2ms preprocess, 197.3ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 5 cars, 2 motorcycles, 1 traffic light, 181.0ms
# Speed: 5.3ms preprocess, 181.0ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 cars, 2 motorcycles, 1 truck, 1 traffic light, 1 umbrella, 191.1ms
# Speed: 4.7ms preprocess, 191.1ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 5 cars, 5 motorcycles, 188.3ms
# Speed: 2.9ms preprocess, 188.3ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 5 cars, 4 motorcycles, 1 truck, 1 traffic light, 198.5ms
# Speed: 4.9ms preprocess, 198.5ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 4 cars, 5 motorcycles, 1 truck, 1 traffic light, 188.6ms
# Speed: 5.6ms preprocess, 188.6ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 5 cars, 1 motorcycle, 1 truck, 1 traffic light, 172.5ms
# Speed: 8.7ms preprocess, 172.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 4 cars, 1 motorcycle, 1 truck, 185.0ms
# Speed: 3.5ms preprocess, 185.0ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 5 cars, 3 motorcycles, 1 truck, 1 traffic light, 178.9ms
# Speed: 3.7ms preprocess, 178.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 6 cars, 2 motorcycles, 1 truck, 1 traffic light, 180.1ms
# Speed: 5.7ms preprocess, 180.1ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 3 cars, 1 motorcycle, 1 traffic light, 182.5ms
# Speed: 4.0ms preprocess, 182.5ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 cars, 2 motorcycles, 1 traffic light, 199.2ms
# Speed: 3.9ms preprocess, 199.2ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 5 cars, 2 motorcycles, 1 traffic light, 215.2ms
# Speed: 10.8ms preprocess, 215.2ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 4 cars, 1 motorcycle, 1 traffic light, 184.8ms
# Speed: 5.5ms preprocess, 184.8ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 cars, 1 traffic light, 190.6ms
# Speed: 3.7ms preprocess, 190.6ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 4 cars, 1 traffic light, 178.4ms
# Speed: 4.3ms preprocess, 178.4ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 4 cars, 2 motorcycles, 1 traffic light, 190.2ms
# Speed: 3.5ms preprocess, 190.2ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 4 cars, 1 motorcycle, 1 traffic light, 190.2ms
# Speed: 3.6ms preprocess, 190.2ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 bicycle, 6 cars, 1 traffic light, 1 umbrella, 192.7ms
# Speed: 11.4ms preprocess, 192.7ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 5 cars, 1 traffic light, 1 umbrella, 191.1ms
# Speed: 5.2ms preprocess, 191.1ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 5 cars, 1 traffic light, 1 umbrella, 207.2ms
# Speed: 4.0ms preprocess, 207.2ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 6 cars, 1 traffic light, 1 umbrella, 211.0ms
# Speed: 5.0ms preprocess, 211.0ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 1 traffic light, 209.2ms
# Speed: 5.2ms preprocess, 209.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 1 traffic light, 218.7ms
# Speed: 6.7ms preprocess, 218.7ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 5 cars, 1 traffic light, 178.5ms
# Speed: 5.5ms preprocess, 178.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 cars, 1 traffic light, 195.9ms
# Speed: 8.1ms preprocess, 195.9ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 5 cars, 2 trucks, 1 traffic light, 208.5ms
# Speed: 9.5ms preprocess, 208.5ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 cars, 1 traffic light, 1 umbrella, 205.0ms
# Speed: 5.4ms preprocess, 205.0ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 cars, 1 truck, 207.3ms
# Speed: 5.5ms preprocess, 207.3ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 cars, 1 truck, 1 traffic light, 197.8ms
# Speed: 5.0ms preprocess, 197.8ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 3 cars, 1 truck, 1 traffic light, 201.5ms
# Speed: 7.2ms preprocess, 201.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 4 cars, 1 truck, 1 traffic light, 176.7ms
# Speed: 5.9ms preprocess, 176.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 1 traffic light, 1 umbrella, 178.3ms
# Speed: 4.8ms preprocess, 178.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 bicycle, 6 cars, 1 truck, 1 traffic light, 182.7ms
# Speed: 4.8ms preprocess, 182.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 7 cars, 1 truck, 1 traffic light, 1 umbrella, 187.2ms
# Speed: 5.8ms preprocess, 187.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 6 cars, 1 truck, 1 traffic light, 1 umbrella, 181.9ms
# Speed: 3.3ms preprocess, 181.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 8 cars, 1 truck, 1 traffic light, 179.4ms
# Speed: 7.1ms preprocess, 179.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 5 cars, 1 truck, 1 traffic light, 1 umbrella, 177.6ms
# Speed: 4.7ms preprocess, 177.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 1 truck, 1 traffic light, 1 umbrella, 164.3ms
# Speed: 5.2ms preprocess, 164.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 cars, 3 motorcycles, 1 traffic light, 193.5ms
# Speed: 5.6ms preprocess, 193.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 4 cars, 2 motorcycles, 1 truck, 1 traffic light, 185.4ms
# Speed: 7.1ms preprocess, 185.4ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 3 cars, 5 motorcycles, 1 traffic light, 171.2ms
# Speed: 8.7ms preprocess, 171.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 4 cars, 4 motorcycles, 1 traffic light, 195.0ms
# Speed: 4.3ms preprocess, 195.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 4 cars, 3 motorcycles, 1 traffic light, 224.7ms
# Speed: 5.6ms preprocess, 224.7ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 car, 2 motorcycles, 1 traffic light, 171.6ms
# Speed: 5.5ms preprocess, 171.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 car, 2 motorcycles, 1 traffic light, 185.5ms
# Speed: 5.4ms preprocess, 185.5ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bicycle, 3 cars, 1 traffic light, 207.7ms
# Speed: 7.0ms preprocess, 207.7ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 6 cars, 3 motorcycles, 1 truck, 1 traffic light, 222.8ms
# Speed: 19.9ms preprocess, 222.8ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 5 cars, 2 trucks, 1 traffic light, 220.6ms
# Speed: 5.9ms preprocess, 220.6ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 6 cars, 2 trucks, 1 traffic light, 273.2ms
# Speed: 4.0ms preprocess, 273.2ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 5 cars, 2 motorcycles, 1 truck, 1 traffic light, 296.1ms
# Speed: 10.7ms preprocess, 296.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 3 cars, 2 motorcycles, 1 truck, 1 traffic light, 1 umbrella, 206.4ms
# Speed: 7.3ms preprocess, 206.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 6 cars, 1 motorcycle, 1 truck, 1 traffic light, 219.8ms
# Speed: 6.5ms preprocess, 219.8ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
